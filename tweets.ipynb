# %%
import json

# %%
listTweet = []
listTweet2 = []

# %%
with open('farlhmd.json') as f:
 for jsonObj in f:
    tweetDict = json.loads(jsonObj)
    listTweet.append(tweetDict)

# %%
x = len(listTweet)
xInt = int(x)
print(xInt)

# %%
for tweet in listTweet:
    print(tweet["renderedContent"])

# %%
with open('depiii.json') as a:
 for jsonObj2 in a:
    tweetDict2 = json.loads(jsonObj2)
    listTweet2.append(tweetDict2)

# %%
i = 0
y = len(listTweet2)
print(y)
while i < len(listTweet2):
    tweetRendered = listTweet2[i]
    print("Tweet depi yang ke", i+1,"di tanggal",tweetRendered["date"],":")
    print(tweetRendered["renderedContent"], "\n")
    i+=1
# Out:
# 100
# Tweet depi yang ke 1 di tanggal 2020-09-11T07:22:49+00:00 :
# @akhibaka @haristyal Parfum refill murah 35ml 25rebu aja✖
# Cheap refill fragrance 35ml only 25k✔✔shopee.co.id/deviealifaa?sm… https://t.co/1LfdOA0mCf
#
# Tweet depi yang ke 2 di tanggal 2020-09-11T07:13:59+00:00 :
# @renaldypjs @SsekarK Aku mencium bau-bau tidak enak nih hhmmh. Gimana kalo kalian beli parfum di aku, parfum refill 35ml cuma 25k aja loh!! shopee.co.id/deviealifaa?sm… https://t.co/tkUPfKRhTj
#
# Tweet depi yang ke 3 di tanggal 2020-09-11T07:12:04+00:00 :
# Ini shopeenyaa shopee.co.id/deviealifaa?sm…
#
# Tweet depi yang ke 4 di tanggal 2020-09-11T07:10:33+00:00 :
# Halo semuanya, aku jualan parfum refill 35ml cuma 25k ajaa! https://t.co/CbUOvOpl6t
#
# Tweet depi yang ke 5 di tanggal 2020-07-21T14:17:23+00:00 :
# Anjrit scroll dm nemu yg bikin plesbek wkwkw
#
# Tweet depi yang ke 6 di tanggal 2016-08-05T03:24:54+00:00 :
# ...
